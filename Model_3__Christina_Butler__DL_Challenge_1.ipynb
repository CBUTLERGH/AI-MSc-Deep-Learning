# %%
# Imports
import keras
from keras.datasets import fashion_mnist
from keras import layers
from keras import Sequential
from keras.layers import Dense

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns

from sklearn.metrics import confusion_matrix

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.regularizers import L1, L2, L1L2

# %% [markdown]
# #Load Data

# %%
# load in the data
fashion_mnist = keras.datasets.fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# #Exploring Fashion MNIST Data

# %%
# Data shape for test and train x
# 60,000 images within the training set
assert x_train.shape == (60000, 28, 28)
assert x_test.shape == (10000, 28, 28)

# %%
# Data shape for test and train y
# 10,000 images within the test set
assert y_train.shape == (60000,)
assert y_test.shape == (10000,)

# %%
plt.figure()
plt.imshow(x_train[10])
plt.colorbar()
plt.grid(False)
plt.show()

# %% [markdown]
# #Preprocessing Data

# %%
labels = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %%
# Normalize pixel values between 0 and 1
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# %%
# One hot encode the output data
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

# %%
class_counts = np.sum(y_train, axis=0)
print(class_counts)
# Out:
# [6000. 6000. 6000. 6000. 6000. 6000. 6000. 6000. 6000. 6000.]

# %%
plt.figure(figsize=(12,15))
for i in range(20):
  plt.subplot(5, 4, i+1)
  plt.imshow(x_train[i], cmap=plt.cm.binary)
  plt.xlabel(labels[np.argmax(y_train[i])])
plt.show()

# %% [markdown]
# #Model 3

# %%
model = keras.Sequential()
model.add(keras.layers.Flatten(input_shape=(28, 28)))
model.add(Dense(units=200, input_dim=4, activation='relu'))
Dropout(0.5),
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=100, activation='relu'))
Dropout(0.5),
model.add(Dense(units=10, activation='softmax'))

optimizer = Adam(learning_rate=0.01)

# %%
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 200)               157000
#
#  dense_1 (Dense)             (None, 100)               20100
#
#  dense_2 (Dense)             (None, 100)               10100
#
#  dense_3 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 188210 (735.20 KB)
# Trainable params: 188210 (735.20 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])


history = model.fit(x_train, y_train,  batch_size=200, epochs=20, callbacks=[early_stop], validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 300/300 [==============================] - 8s 15ms/step - loss: 0.5649 - accuracy: 0.8025 - val_loss: 0.4744 - val_accuracy: 0.8238
# Epoch 2/20
# 300/300 [==============================] - 3s 9ms/step - loss: 0.3834 - accuracy: 0.8624 - val_loss: 0.4017 - val_accuracy: 0.8541
# Epoch 3/20
# 300/300 [==============================] - 3s 9ms/step - loss: 0.3416 - accuracy: 0.8746 - val_loss: 0.3673 - val_accuracy: 0.8653
# Epoch 4/20
# 300/300 [==============================] - 4s 12ms/step - loss: 0.3143 - accuracy: 0.8836 - val_loss: 0.3641 - val_accuracy: 0.8682
# Epoch 5/20
# 300/300 [==============================] - 3s 9ms/step - loss: 0.2956 - accuracy: 0.8906 - val_loss: 0.3610 - val_accuracy: 0.8708
# Epoch 6/20
# 300/300 [==============================] - 3s 9ms/step - loss: 0.2782 - accuracy: 0.8962 - val_loss: 0.3493 - val_accuracy: 0.8752
# Epoch 7/20
# 300/300 [==============================] - 3s 9ms/step - loss: 0.2639 - accuracy: 0.9007 - val_loss: 0.3386 - val_accuracy: 0.8787
# Epoch 8/20
# 300/300 [==============================] - 3s 10ms/step - loss: 0.2571 - accuracy: 0.9032 - val_loss: 0.3325 - val_accuracy: 0.8804
# Epoch 9/20
# 300/300 [==============================] - 3s 10ms/step - loss: 0.2464 - accuracy: 0.9069 - val_loss: 0.3459 - val_accuracy: 0.8767
# Epoch 10/20
# 300/300 [==============================] - 3s 9ms/step - loss: 0.2352 - accuracy: 0.9117 - val_loss: 0.3398 - val_accuracy: 0.8811
# Epoch 11/20
# 300/300 [==============================] - 3s 9ms/step - loss: 0.2256 - accuracy: 0.9149 - val_loss: 0.3307 - val_accuracy: 0.8843
# Epoch 12/20
# 300/300 [==============================] - 3s 9ms/step - loss: 0.2200 - accuracy: 0.9171 - val_loss: 0.3478 - val_accuracy: 0.8839
# Epoch 13/20
# 300/300 [==============================] - 4s 12ms/step - loss: 0.2116 - accuracy: 0.9209 - val_loss: 0.3243 - val_accuracy: 0.8886
# Epoch 14/20
# 300/300 [==============================] - 3s 9ms/step - loss: 0.2064 - accuracy: 0.9222 - val_loss: 0.3521 - val_accuracy: 0.8771
# Epoch 15/20
# 300/300 [==============================] - 3s 9ms/step - loss: 0.1976 - accuracy: 0.9256 - val_loss: 0.3261 - val_accuracy: 0.8897
# Epoch 16/20
# 300/300 [==============================] - 3s 9ms/step - loss: 0.1921 - accuracy: 0.9275 - val_loss: 0.3234 - val_accuracy: 0.8913
# Epoch 17/20
# 300/300 [==============================] - 3s 12ms/step - loss: 0.1877 - accuracy: 0.9291 - val_loss: 0.3287 - val_accuracy: 0.8919
# Epoch 18/20
# 300/300 [==============================] - 3s 10ms/step - loss: 0.1837 - accuracy: 0.9306 - val_loss: 0.3485 - val_accuracy: 0.8808
# Epoch 19/20
# 300/300 [==============================] - 3s 9ms/step - loss: 0.1749 - accuracy: 0.9324 - val_loss: 0.3301 - val_accuracy: 0.8891

# %% [markdown]
# #Evaluation

# %%
# measure accuracy
test_loss, test_acc=model.evaluate(x_test, y_test)
print("test accuracy:",test_acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3301 - accuracy: 0.8891
# test accuracy: 0.8891000151634216

# %%
# Predict the class probabilities for the test set
y_pred_probs = model.predict(x_test)

# Convert the predictions from one-hot encoded vectors to integers
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test, axis=1)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
# Generate the confusion matrix
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=labels, yticklabels=labels)
plt.title('Confusion Matrix')
plt.ylabel('Actual Labels')
plt.xlabel('Predicted Labels')
plt.show()

# %%
# plot the history of the training
import matplotlib.pyplot as plt

# summarize the history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'], loc='upper left')
plt.show()

# %%
# summarize the history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','test'], loc='upper left')
plt.show()

# %%
# clear session
keras.backend.clear_session()

# set random seed
keras.utils.set_random_seed(0) # set all random seeds for the program (Python, NumPy, and TensorFlow)

# %%
#early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=2)
